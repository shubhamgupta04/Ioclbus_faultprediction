# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("D:\Shubham\Work\IOCL\Fw_ IOCL Raw CAN data request from Layer 3\PROPDL19012382295_Rawcan_24_06_23.csv")

# %%
df.head()
# Out:
#    vin               | subcategory       | can_type | time_bucket | created_timestamp               | updated_timestamp               | category   | correlationid | header_timestamp                | header_to | messageid                            | messagetype       | packet_status | priority | state                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
# ...
