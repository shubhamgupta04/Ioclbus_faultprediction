# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("D:\Shubham\Work\IOCL\Fw_ IOCL Raw CAN data request from Layer 3\PROPDL19012382295_Rawcan_24_06_23_testing.csv",header= None)
df.head()
# Out:
#                                                  0                    1    \
# 0   vin               | subcategory       | can_t...                  NaN
# 1  -------------------+-------------------+------...                  NaN
# 2   PROPDL19012382295 | VehicleGenericCan |  Gene...  data:"AgICAgICAQA="
# 3   PROPDL19012382295 | VehicleGenericCan |  Gene...  data:"AQAAAAAAAAA="
# 4   PROPDL19012382295 | VehicleGenericCan |  Gene...  data:"AQAAAAAAAAA="
#
#       2                        3                    4       5    \
# 0     NaN                      NaN                  NaN     NaN
# 1     NaN                      NaN                  NaN     NaN
# 2  dlc:8}  {"identifier":419361057  data:"VQABVVUBIVU="  dlc:8}
# 3  dlc:8}  {"identifier":419378471  data:"ARkyHh5GAAA="  dlc:8}
# 4  dlc:8}  {"identifier":419378471  data:"ARkyHh5GAAA="  dlc:8}
#
#                        6                    7    \
# 0                      NaN                  NaN
# ...

# %%
# Total Rows = 2768, columns= 177 
df.shape
# Out:
# (2769, 177)

# %%
df.iloc[0,0]
# Out:
# ' vin               | subcategory       | can_type | time_bucket | created_timestamp               | updated_timestamp               | category   | correlationid | header_timestamp                | header_to | messageid                            | messagetype       | packet_status | priority | state                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2769, step=1)

# %%
[0, 1, 102, 103, 104, 205, 206, 207, 308, 309, 310, 411, 412, 413, 514, 515, 516, 617, 618, 619, 720, 721, 722, 823, 824, 825, 926, 927, 928, 1029, 1030, 1031, 1132, 1133, 1134, 1235, 1236, 1237, 1338, 1339, 1340, 1441, 1442, 1443, 1544, 1545, 1546, 1647, 1648, 1649, 1750, 1751, 1752, 1853, 1854, 1855, 1956, 1957, 1958, 2059, 2060, 2061, 2162, 2163, 2164, 2265, 2266, 2267, 2368, 2369, 2370, 2471, 2472, 2473, 2574, 2575, 2576, 2677, 2678, 2679, 2767, 2768]

# %%
lst = [1,2,103,104,105,206,207,208,309,310,311,412,413,414,515,516,517,618,619,620,721,722,723,824,825,826,927,928,929,1030,1031,1032,1133,1134,1135,1236,1237,1238,1339,1340,1341,1442,1443,1444,1545,1546,1547,1648,1649,1650,1751,1752,1753,1854,1855,1856,1957,1958,1959,2060,2061,2062,2163,2164,2165,2266,2267,2268,2369,2370,2371,2472,2473,2474,2575,2576,2577,2678,2679,2680,2768,2769],
for i in range(len(lst))
    lst[i] = lst[i] - 1
    print(lst)
# Out:
#   Cell In[8], line 2
#     for i in range(len(lst))
#                             ^
# SyntaxError: expected ':'

# %%
df.iloc[0,:]
df = df.drop(labels=lst, axis =0)
df
df.head()

# %%
header_lst = header[0].split(\"|\")
print(header_lst)
print(len(header_lst))

# %%
row_lst = df.iloc[1,0].split(\"|\")
len(row_lst)"

# %%
lst = [1,2,103,104,105,206,207,208,309,310,311,412,413,414,515,516,517,618,619,620,721,722,723,824,825,826,927,928,929,1030,1031,1032,1133,1134,1135,1236,1237,1238,1339,1340,1341,1442,1443,1444,1545,1546,1547,1648,1649,1650,1751,1752,1753,1854,1855,1856,1957,1958,1959,2060,2061,2062,2163,2164,2165,2266,2267,2268,2369,2370,2371,2472,2473,2474,2575,2576,2577,2678,2679,2680,2769]
for i in range(len(lst))
    lst[i] = lst[i] -1
print(lst[i])
# Out:
#   Cell In[6], line 2
#     for i in range(len(lst)),
#                              ^
# SyntaxError: expected ':'

# %%
#df = pd.read_csv('RawCan.csv',on_bad_lines='skip',skiprows = [1,103,104,105,206,207,208,309,310,311,412,413,414,515,516,517,618,619,620,721,722,723,824,825,826,927,928,929,1030,1031,1032,1133,1134,1135,1236,1237,1238,1339,1340,1341,1442,1443,1444,1545,1546,1547,1648,1649,1650,1751,1752,1753,1854,1855,1856,1957,1958,1959,2060,2061,2062,2163,2164,2165,2266,2267,2268,2369,2370,2371,2472,2473,2474,2575,2576,2577,2678,2679,2680,2769])

# %%
#df.drop([0,1,2,103,104,105,206,207,208,309,310,311,412,413,414,515,516,517,618,619,620,721,722,723,824,825,826,927,928,929,1030,1031,1032,1133,1134,1135,1236,1237,1238,1339,1340,1341,1442,1443,1444,1545,1546,1547,1648,1649,1650,1751,1752,1753,1854,1855,1856,1957,1958,1959,2060,2061,2062,2163,2164,2165,2266,2267,2268,2369,2370,2371,2472,2473,2474,2575,2576,2577,2678,2679,2680],axis=0)

# %%
df.head()

# %%
# Checking missing values
df.isna().sum()

# %%
# check duplicate values
df.duplicated().sum()

# %%
# Check Null and Dtypes
df.info()

# %%
# check number of unique values of each column
df.nunique()

# %%
# Check statistics of data set
df.describe()

# %%
df_data = df.get(0)
df_data

# %%
df.isnull().sum

# %%
df1 = df.iloc[:, 0]
df1

# %%
df1 = df.iloc[:,:1]
print(df1)
df1.shape

# %%
split_column0 = df[:,0]
x = split_column0.split("|")
print(split_column0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File D:\Program Files\Anaconda\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File D:\Program Files\Anaconda\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\Program Files\Anaconda\Lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 split_column0 = df[:,0]
#       2 x = split_column0.split("|")
#       3 print(split_column0)
#
# ...

# %%
df.dtypes
# Out:
#  vin               | subcategory       | can_type | time_bucket | created_timestamp               | updated_timestamp               | category   | correlationid | header_timestamp                | header_to | messageid                            | messagetype       | packet_status | priority | state                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          
# ...

# %%
df_test= pd.DataFrame(df)

# %%
df_test.dtypes
# Out:
#  vin               | subcategory       | can_type | time_bucket | created_timestamp               | updated_timestamp               | category   | correlationid | header_timestamp                | header_to | messageid                            | messagetype       | packet_status | priority | state                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          
# ...

# %%
# Out:
#       vin               | subcategory       | can_type | time_bucket | created_timestamp               | updated_timestamp               | category   | correlationid | header_timestamp                | header_to | messageid                            | messagetype       | packet_status | priority | state                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     
# ...

# %%
#df_train=df[0,0]
df_test = df.astype('category')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 4
#       1 #df_train=df[0,0]
#       2 df_test = df.astype('category')
# ----> 4 x = df_test.split("|")
#       5 print(split_column0)
#
# File D:\Program Files\Anaconda\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'split'

# %%
df_test.dtypes
# Out:
#  vin               | subcategory       | can_type | time_bucket | created_timestamp               | updated_timestamp               | category   | correlationid | header_timestamp                | header_to | messageid                            | messagetype       | packet_status | priority | state                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          
# ...
